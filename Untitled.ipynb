# %%
import yfinance, pandas, numpy, ta, sklearn, matplotlib, seaborn, transformers, econml
print("✅ Todo listo para el proyecto!")
# Out:
# ✅ Todo listo para el proyecto!
